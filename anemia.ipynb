# %% [markdown]
# <a href="https://colab.research.google.com/github/ayakhefifi4-pixel/coffee-game/blob/main/anemia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data= pd.read_csv('anemia.csv')

# %%
data.head()
# Out:
#    Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0       1        14.9  22.7  29.1  83.7       0
# 1       0        15.9  25.4  28.3  72.0       0
# 2       0         9.0  21.5  29.6  71.2       1
# 3       0        14.9  16.0  31.4  87.5       0
# 4       1        14.7  22.0  28.2  99.5       0

# %%
data.describe()
# Out:
#             Gender   Hemoglobin          MCH         MCHC          MCV  \
# count  1421.000000  1421.000000  1421.000000  1421.000000  1421.000000
# mean      0.520760    13.412738    22.905630    30.251232    85.523786
# std       0.499745     1.974546     3.969375     1.400898     9.636701
# min       0.000000     6.600000    16.000000    27.800000    69.400000
# 25%       0.000000    11.700000    19.400000    29.000000    77.300000
# 50%       1.000000    13.200000    22.700000    30.400000    85.300000
# 75%       1.000000    15.000000    26.200000    31.400000    94.200000
# max       1.000000    16.900000    30.000000    32.500000   101.600000
#
#             Result
# count  1421.000000
# mean      0.436312
# std       0.496102
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1421 entries, 0 to 1420
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      1421 non-null   int64
#  1   Hemoglobin  1421 non-null   float64
#  2   MCH         1421 non-null   float64
#  3   MCHC        1421 non-null   float64
#  4   MCV         1421 non-null   float64
#  5   Result      1421 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 66.7 KB

# %%
features =['Gender'	,'Hemoglobin',	'MCH',	'MCHC'	,'MCV']

# %%
x=data[features]

# %%
y=data['Result']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test ,y_train ,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
y_test.describe()
# Out:
# count    427.000000
# mean       0.426230
# std        0.495108
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Result, dtype: float64

# %%
y_train.describe()
# Out:
# count    994.000000
# mean       0.440644
# std        0.496714
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Result, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)

# %%
y_test
# Out:
# 51      1
# 289     0
# 677     0
# 1005    0
# 367     1
#        ..
# 1367    0
# 721     0
# 706     0
# 352     0
# 788     1
# Name: Result, Length: 427, dtype: int64

# %%
score=model.score(x_test,y_test)

# %%
score
# Out:
# 1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a PairGrid for all feature distributions
g = sns.pairplot(data, hue='Result', kind='hist', diag_kind='kde')
plt.show()

# %%
# Plot the histogram
plt.figure(figsize=(8, 5)) # Optional: adjust figure size
plt.hist(data['MCH'], bins=20, color='skyblue', edgecolor='black') # You can adjust the number of bins and color

# Add labels and a title
plt.title('Distribution ')
plt.xlabel('nn')
plt.ylabel('Frequency')

# Display the plot
# Out:
# Text(0, 0.5, 'Frequency')
